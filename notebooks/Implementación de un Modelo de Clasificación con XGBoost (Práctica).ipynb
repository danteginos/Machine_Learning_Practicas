# %% [markdown]
# #### Implementación de un Modelo de Clasificación con XGBoost (Práctica)
# Objetivo: Guiar a los estudiantes a través de la implementación de un modelo de clasificación utilizando XGBoost con el dataset Wine Quality disponible en sklearn, identificar y corregir al menos 5 errores en el código proporcionado.
#
# *Instrucciones
#
# *Carga del Dataset:
#  Utilizar el dataset Wine Quality de sklearn.
# Implementación del Código:
# A continuación se proporciona un código con errores. Los estudiantes deben identificar y corregir los errores para que el modelo funcione correctamente.

# %%
import pandas as pd
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import xgboost as xgb
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
# Cargar el dataset
wine = load_wine()
X = pd.DataFrame(wine.data, columns=wine.feature_names)
y = pd.Series(wine.target)

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Escalar las características
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

# Crear y entrenar el modelo
model = xgb.XGBClassifier(use_label_encoder=False)
model.fit(X_train, y_train)

# Realizar predicciones
y_pred = model.predict(X_test)

# Evaluar el modelo
accuracy = accuracy_score(y_test, y_pred)
print(f'Exactitud: {accuracy}')
print('Informe de Clasificación:')
print(classification_report(y_test, y_pred))

# Matriz de Confusión
conf_matrix = confusion_matrix(y_test, y_pred)
print('Matriz de Confusión:')
print(conf_matrix)
# Out:
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [13:55:59] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Exactitud: 0.9814814814814815
# Informe de Clasificación:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       0.95      1.00      0.98        21
#            2       1.00      0.93      0.96        14
#
#     accuracy                           0.98        54
#    macro avg       0.98      0.98      0.98        54
# weighted avg       0.98      0.98      0.98        54
#
# Matriz de Confusión:
# [[19  0  0]
#  [ 0 21  0]
#  [ 0  1 13]]

# %% [markdown]
# #### Error : Esta usando fit_transform en X_train y X-test , Debe usar transform en el X_test
# #### Debería añadir eval_metric para evitar warnings.
